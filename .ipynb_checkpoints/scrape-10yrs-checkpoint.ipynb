# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
years = [
    '2009',
    '2011',
    '2013',
    '2015',
    '2017',
    '2019',
    '2021'
]

# %%
def number_of_results_in_year(year):
    year_href = "https://www.nysenate.gov/search/legislation?sort=desc&type=f_bill&searched=true&bill_session_year=" + str(year) + "&bill_status=SIGNED_BY_GOV&page=1"
    raw_html = requests.get(year_href).content
    soup_year = BeautifulSoup(raw_html, "html.parser")
    
    results_count_element = soup_year.find("div", class_="ds-search-extra")
    results_count_string = results_count_element.text.strip()
    results_count = re.findall("[0-9]+", results_count_string)
    results_count_number = int(results_count[0])
    total_pages = int(results_count_number / 10) + 1
    return total_pages

# %%
def signed_bills(href):
    raw_html = requests.get(href).content
    soup_doc = BeautifulSoup(raw_html, "html.parser")
    
    all_bills = soup_doc.find_all("div", class_="c-block c-list-item c-block-legislation")

    signed_bills_list_of_dicts = []

    for bill in all_bills:
        bill_number = bill.find("h3", class_="c-bill-num").text.replace("\n", "").replace("Bill ", "").strip()
        bill_link = bill.find("h3", class_="c-bill-num").find("a")['href']
        bill_description = bill.find("p", class_="c-bill-descript").text.replace("\n", "")
        bill_date = bill.find("p", class_="c-bill-update--date").text.replace("\n", "").replace("|  Signed by Governor", "")
        bill_sponsor_tag = bill.find("p", class_="c-bill-update--sponsor")
        if bill_sponsor_tag != None:
            bill_sponsor = bill_sponsor_tag.text.replace("\n", "").replace("Sponsor:", "")
        else:
            bill_sponsor = ""
        signed_bills_list_of_dicts.append(
            {"bill_number": bill_number, "bill_link": "https://www.nysenate.gov" + bill_link, "bill_description": bill_description,
             "bill_date": bill_date, "bill_sponsor": bill_sponsor}
        )
        
    
    return signed_bills_list_of_dicts

# %%
page_numbers_main_list = []

for year in years:
    pages_to_loop = number_of_results_in_year(year)
    page_numbers = range(1, pages_to_loop + 1)
    for page in page_numbers:
        href = "https://www.nysenate.gov/search/legislation?sort=desc&type=f_bill&searched=true&bill_session_year=2021&bill_status=SIGNED_BY_GOV&page=" + str(page)
        bill_list = signed_bills(href)
        page_numbers_main_list.extend(bill_list)

        print(f"calling signed bills for year {year} in page {page}")
# Out:
# calling signed bills for year 2009 in page 1
# calling signed bills for year 2009 in page 2
# calling signed bills for year 2009 in page 3
# calling signed bills for year 2009 in page 4
# calling signed bills for year 2009 in page 5
# calling signed bills for year 2009 in page 6
# calling signed bills for year 2009 in page 7
# calling signed bills for year 2009 in page 8
# calling signed bills for year 2009 in page 9
# calling signed bills for year 2009 in page 10
# calling signed bills for year 2009 in page 11
# calling signed bills for year 2009 in page 12
# calling signed bills for year 2009 in page 13
# calling signed bills for year 2009 in page 14
# calling signed bills for year 2009 in page 15
# calling signed bills for year 2009 in page 16
# calling signed bills for year 2009 in page 17
# calling signed bills for year 2009 in page 18
# calling signed bills for year 2009 in page 19
# calling signed bills for year 2009 in page 20
# calling signed bills for year 2009 in page 21
# calling signed bills for year 2009 in page 22
# calling signed bills for year 2009 in page 23
# calling signed bills for year 2009 in page 24
# calling signed bills for year 2009 in page 25
# calling signed bills for year 2009 in page 26
# calling signed bills for year 2009 in page 27
# calling signed bills for year 2009 in page 28
# calling signed bills for year 2009 in page 29
# calling signed bills for year 2009 in page 30
# calling signed bills for year 2009 in page 31
# calling signed bills for year 2009 in page 32
# calling signed bills for year 2009 in page 33
# calling signed bills for year 2009 in page 34
# calling signed bills for year 2011 in page 60
# calling signed bills for year 2011 in page 61
# calling signed bills for year 2011 in page 62
# calling signed bills for year 2011 in page 63
# calling signed bills for year 2011 in page 64
# calling signed bills for year 2011 in page 65
# calling signed bills for year 2011 in page 66
# calling signed bills for year 2011 in page 67
# calling signed bills for year 2011 in page 68
# calling signed bills for year 2011 in page 69
# calling signed bills for year 2011 in page 70
# calling signed bills for year 2013 in page 1
# calling signed bills for year 2013 in page 2
# calling signed bills for year 2013 in page 3
# calling signed bills for year 2013 in page 4
# calling signed bills for year 2013 in page 5
# calling signed bills for year 2013 in page 6
# calling signed bills for year 2013 in page 7
# calling signed bills for year 2013 in page 8
# calling signed bills for year 2013 in page 9
# calling signed bills for year 2013 in page 10
# calling signed bills for year 2013 in page 11
# calling signed bills for year 2013 in page 12
# calling signed bills for year 2013 in page 13
# calling signed bills for year 2013 in page 14
# calling signed bills for year 2013 in page 15
# calling signed bills for year 2013 in page 16
# calling signed bills for year 2013 in page 17
# calling signed bills for year 2013 in page 18
# calling signed bills for year 2013 in page 19
# calling signed bills for year 2013 in page 20
# calling signed bills for year 2013 in page 21
# calling signed bills for year 2013 in page 22
# calling signed bills for year 2013 in page 23
# calling signed bills for year 2013 in page 24
# calling signed bills for year 2013 in page 25
# calling signed bills for year 2013 in page 26
# calling signed bills for year 2013 in page 27
# calling signed bills for year 2013 in page 28
# calling signed bills for year 2013 in page 29
# calling signed bills for year 2013 in page 30
# calling signed bills for year 2013 in page 31
# calling signed bills for year 2013 in page 32
# calling signed bills for year 2013 in page 33
# calling signed bills for year 2013 in page 34
# calling signed bills for year 2013 in page 35
# calling signed bills for year 2013 in page 36
# calling signed bills for year 2013 in page 37
# calling signed bills for year 2013 in page 38
# calling signed bills for year 2013 in page 39
# calling signed bills for year 2013 in page 40
# calling signed bills for year 2013 in page 41
# calling signed bills for year 2013 in page 42
# calling signed bills for year 2013 in page 43
# calling signed bills for year 2013 in page 44
# calling signed bills for year 2013 in page 45
# calling signed bills for year 2013 in page 46
# calling signed bills for year 2013 in page 47
# calling signed bills for year 2013 in page 48
# calling signed bills for year 2013 in page 49
# calling signed bills for year 2013 in page 50
# calling signed bills for year 2013 in page 51
# calling signed bills for year 2013 in page 52
# calling signed bills for year 2013 in page 53
# calling signed bills for year 2013 in page 54
# calling signed bills for year 2013 in page 55
# calling signed bills for year 2013 in page 56
# calling signed bills for year 2013 in page 57
# calling signed bills for year 2013 in page 58
# calling signed bills for year 2013 in page 59
# calling signed bills for year 2013 in page 60
# calling signed bills for year 2013 in page 61
# calling signed bills for year 2013 in page 62
# calling signed bills for year 2013 in page 63
# calling signed bills for year 2013 in page 64
# calling signed bills for year 2013 in page 65
# calling signed bills for year 2013 in page 66
# calling signed bills for year 2013 in page 67
# calling signed bills for year 2013 in page 68
# calling signed bills for year 2015 in page 1
# calling signed bills for year 2015 in page 2
# calling signed bills for year 2015 in page 3
# calling signed bills for year 2015 in page 4
# calling signed bills for year 2015 in page 5
# calling signed bills for year 2015 in page 6
# calling signed bills for year 2015 in page 7
# calling signed bills for year 2015 in page 8
# calling signed bills for year 2015 in page 9
# calling signed bills for year 2015 in page 10
# calling signed bills for year 2015 in page 11
# calling signed bills for year 2021 in page 47
# calling signed bills for year 2021 in page 48
# calling signed bills for year 2021 in page 49
# calling signed bills for year 2021 in page 50
# calling signed bills for year 2021 in page 51
# calling signed bills for year 2021 in page 52
# calling signed bills for year 2021 in page 53
# calling signed bills for year 2021 in page 54
# calling signed bills for year 2021 in page 55
# calling signed bills for year 2021 in page 56
# calling signed bills for year 2021 in page 57
# calling signed bills for year 2021 in page 58
# calling signed bills for year 2021 in page 59
# calling signed bills for year 2021 in page 60
# calling signed bills for year 2021 in page 61
# calling signed bills for year 2021 in page 62
# calling signed bills for year 2021 in page 63
# calling signed bills for year 2021 in page 64
# calling signed bills for year 2021 in page 65
# calling signed bills for year 2021 in page 66
# calling signed bills for year 2021 in page 67
# calling signed bills for year 2021 in page 68
# calling signed bills for year 2021 in page 69
# calling signed bills for year 2021 in page 70

# %%
import pandas as pd
df_bills = pd.DataFrame(page_numbers_main_list)
df_bills
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#      bill_number                                          bill_link  \
# 0          A9002  https://www.nysenate.gov/legislation/bills/202...
# 1          S8748  https://www.nysenate.gov/legislation/bills/202...
# 2          S8715  https://www.nysenate.gov/legislation/bills/202...
# 3          A9607  https://www.nysenate.gov/legislation/bills/202...
# 4          S7619  https://www.nysenate.gov/legislation/bills/202...
# ...          ...                                                ...
# 4745       A1251  https://www.nysenate.gov/legislation/bills/202...
# 4746       A1252  https://www.nysenate.gov/legislation/bills/202...
# 4747       S1197  https://www.nysenate.gov/legislation/bills/202...
# 4748       S2733  https://www.nysenate.gov/legislation/bills/202...
# 4749        S882  https://www.nysenate.gov/legislation/bills/202...
#
#                                        bill_description  \
# 0                           DEBT SERVICE FUND--GENER...
# 1                           Enacts major components ...
# 2                           Provides for emergency a...
# 3                           Extends the time for cer...
# 4                           Extends the effectivenes...
# ...                                                 ...
# 4745                        Relates to the direct de...
# 4746                        Relates to the authority...
# 4747                        Prohibits the inclusion ...
# 4748                        Reduces the number of si...
# 4749                        Relates to certain data ...
#
#                                               bill_date  \
# 0                             April 9, 2022  |  Sign...
# 1                             April 9, 2022  |  Sign...
# 2                             April 4, 2022  |  Sign...
# 3                             April 1, 2022  |  Sign...
# 4                             March 26, 2022  |  Sig...
# ...                                                 ...
# 4745                          January 28, 2021  |  S...
# 4746                          January 28, 2021  |  S...
# 4747                          January 28, 2021  |  S...
# 4748                          January 28, 2021  |  S...
# 4749                          January 28, 2021  |  S...
#
#                                            bill_sponsor
# 0
# 1                            JACKSON                ...
# 2                            KRUEGER                ...
# 3                            HEASTIE                ...
# 4                            MAYER
# ...                                                 ...
# 4745                         REYES
# 4746                         GUNTHER                ...
# 4747                         PERSAUD                ...
# 4748                           MAY
# 4749                         PERSAUD                ...
#
# [4750 rows x 5 columns]

# %%
def signed_bills_law_section(href):
    raw_html = requests.get(href).content
    soup_doc = BeautifulSoup(raw_html, "html.parser")
    
    law_section = soup_doc.find_all("div", class_="c-block c-bill-section c-bill--details")[0].find_all("dd")[1].text
    return law_section

# %%
bill_new_numbers = [bill_dict["bill_number"] for bill_dict in page_numbers_main_list]

# %%
bill_numbers_main_list = []
for bill in bill_new_numbers:
    href = "https://www.nysenate.gov/legislation/bills/" + year + "/" + bill
    bill_list_sections = signed_bills_law_section(href)
    
    bill_numbers_main_list.append({"bill_number": bill, "bill_section": bill_list_sections})

# %%
df_bill_sections = pd.DataFrame(bill_numbers_main_list)
pd.set_option("display.max_colwidth", None)
df_bill_sections
# Out:
#      bill_number               bill_section
# 0          A9002               Budget Bills
# 1          S8748          Civil Service Law
# 2          S8715             Appropriations
# 3          A9607            Public Officers
# 4          S7619                  Education
# ...          ...                        ...
# 4745       A1251  Workers' Compensation Law
# 4746       A1252              Insurance Law
# 4747       S1197                  Labor Law
# 4748       S2733               Election Law
# 4749        S882        Social Services Law
#
# [4750 rows x 2 columns]

# %%
df_bills.set_index('bill_number').join(df_bill_sections.set_index('bill_number'))
# Out:
#                                                          bill_link  \
# bill_number
# A1237        https://www.nysenate.gov/legislation/bills/2021/a1237
# A1237        https://www.nysenate.gov/legislation/bills/2021/a1237
# A1237        https://www.nysenate.gov/legislation/bills/2021/a1237
# A1237        https://www.nysenate.gov/legislation/bills/2021/a1237
# A1237        https://www.nysenate.gov/legislation/bills/2021/a1237
# ...                                                            ...
# S905          https://www.nysenate.gov/legislation/bills/2021/s905
# S905          https://www.nysenate.gov/legislation/bills/2021/s905
# S905          https://www.nysenate.gov/legislation/bills/2021/s905
# S905          https://www.nysenate.gov/legislation/bills/2021/s905
# S905          https://www.nysenate.gov/legislation/bills/2021/s905
#
#                                                                                                                                      bill_description  \
# bill_number
# A1237                              Provides for the remote conduct of certain practices and procedures relating to board meetings
# A1237                              Provides for the remote conduct of certain practices and procedures relating to board meetings
# A1237                              Provides for the remote conduct of certain practices and procedures relating to board meetings
# A1237                              Provides for the remote conduct of certain practices and procedures relating to board meetings
# A1237                              Provides for the remote conduct of certain practices and procedures relating to board meetings
# ...                                                                                                                                               ...
# S905                                                   Relates to the establishment of the real property tax exemption task force
# S905                                                   Relates to the establishment of the real property tax exemption task force
# S905                                                   Relates to the establishment of the real property tax exemption task force
# S905                                                   Relates to the establishment of the real property tax exemption task force
# S905                                                   Relates to the establishment of the real property tax exemption task force
#
#                                                                                          bill_date  \
# bill_number
# A1237                                November 8, 2021  |  Signed by Governor
# A1237                                November 8, 2021  |  Signed by Governor
# A1237                                November 8, 2021  |  Signed by Governor
# A1237                                November 8, 2021  |  Signed by Governor
# A1237                                November 8, 2021  |  Signed by Governor
# ...                                                                                            ...
# S905                                    June 11, 2021  |  Signed by Governor
# S905                                    June 11, 2021  |  Signed by Governor
# S905                                    June 11, 2021  |  Signed by Governor
# S905                                    June 11, 2021  |  Signed by Governor
# S905                                    June 11, 2021  |  Signed by Governor
#
#                                                      bill_sponsor  \
# bill_number
# A1237                                 PAULIN
# A1237                                 PAULIN
# A1237                                 PAULIN
# A1237                                 PAULIN
# A1237                                 PAULIN
# ...                                                           ...
# S905                                HARCKHAM
# S905                                HARCKHAM
# S905                                HARCKHAM
# S905                                HARCKHAM
# S905                                HARCKHAM
#
#                          bill_section
# bill_number
# A1237        Business Corporation Law
# A1237        Business Corporation Law
# A1237        Business Corporation Law
# A1237        Business Corporation Law
# A1237        Business Corporation Law
# ...                               ...
# S905           Real Property Taxation
# S905           Real Property Taxation
# S905           Real Property Taxation
# S905           Real Property Taxation
# S905           Real Property Taxation
#
# [33026 rows x 5 columns]
